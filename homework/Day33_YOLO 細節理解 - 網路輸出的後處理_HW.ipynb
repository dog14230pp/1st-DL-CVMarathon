# %% [markdown]
# ## YOLO 細節理解 - 網路輸出的後處理
# 今天的課程，我們說明了NMS在yolo中運作的情形:
# * NMS在YOLO的實際運作以每一個類別為主，各別執行NMS。
# * YOLO 在NMS中採用的信心度為「每個 bbox 包含各類別的信心度」

# %% [markdown]
# ### 作業
# 在NMS流程中，IoU重疊率參數(nms_threshold )調高，試著思考一下輸出的預測框會有甚麼變化?
# Hint: 可以回頭看今天介紹的內容，思考輸出的預測框變多或變少?

# %%
#由投影片: "IoU > nms_threshold ，代表兩兩者框住同一個物體"可知
#只要IoU > nms_threshold成立，信心度較低的框就會被移除
#因此，若nms_threshold設太低，就會使得很多框被移除(因為被視為框住同一物體)
#而若nms_threshold設高，則會使得很多框被留下(被視為框住不同物體)
#得證

#補充: https://www.cupoy.com/qa/club/ai_tw/0000016E62FABB7A000000016375706F795F72656C656173654B5741535354434C5542/0000016F7D7BD5D1000001916375706F795F72656C656173655155455354
# Out:
# '\n你的答案\n'
