# %% [markdown]
# ## Day34.YOLO 細節理解 - 損失函數
# 今天的課程，我們講述了
# * 損失函數是描述模型預測出來的結果和實際的差異的依據
# * YOLO 損失函數的設計包含物件位置的定位與物件類別辨識
# * YOLO損失函數透過超參數設定模型有不同的辨識能力

# %% [markdown]
# ### 作業
# 仔細觀察，bbox 寬高計算損失方式和bbox中心計算損失方式有哪邊不一樣嗎? 為什麼要有不同的設計?
# ![title](loss function.png)

# %%
#此部分仍需研究

#https://stats.stackexchange.com/questions/332907/yolo-loss-function-width-and-height-component-explanation

#bbox 寬高計算損失方式:多一開根號計算

#Reason:
#基本上，在同樣的差距中(EX 差距 = 5px)
#若該差距是出現在大物體當中，則其影響會比較低(5px:1000px)
#然而若差距是出現在小物體當中，則其影響較大(5px:20px)
#開根號可以縮小這兩者間不對等的影響力
# Out:
# '\n你的答案\n'
