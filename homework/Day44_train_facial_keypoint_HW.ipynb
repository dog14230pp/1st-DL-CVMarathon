# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd gdrive/'My Drive'
os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.0
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# /content/gdrive/My Drive/cupoy_cv_part4

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0077 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00243, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 0.0019 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00243 to 0.00192, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00192 to 0.00189, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00189 to 0.00185, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00185 to 0.00176, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 0.0011 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00176 to 0.00175, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 9.1998e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00175 to 0.00157, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 7.8063e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00157 to 0.00154, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 6.9667e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00154 to 0.00138, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 6.1891e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00138 to 0.00123, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 5.8238e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00123 to 0.00121, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 5.2815e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00121 to 0.00113, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 4.9444e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00113 to 0.00112, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 4.6621e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00112 to 0.00102, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 4.3353e-04 - val_loss: 9.8418e-04
#
# Epoch 00015: val_loss improved from 0.00102 to 0.00098, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 4.0777e-04 - val_loss: 9.3841e-04
#
# Epoch 00016: val_loss improved from 0.00098 to 0.00094, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 3.8746e-04 - val_loss: 8.9897e-04
#
# Epoch 00017: val_loss improved from 0.00094 to 0.00090, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 3.7156e-04 - val_loss: 8.7953e-04
#
# Epoch 00018: val_loss improved from 0.00090 to 0.00088, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 3.6896e-04 - val_loss: 8.9432e-04
#
# Epoch 00019: val_loss did not improve from 0.00088
# Epoch 20/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 3.4219e-04 - val_loss: 8.9433e-04
#
# Epoch 00020: val_loss did not improve from 0.00088
# Epoch 21/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 3.2974e-04 - val_loss: 8.5867e-04
#
# Epoch 00021: val_loss improved from 0.00088 to 0.00086, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 3.1542e-04 - val_loss: 8.5957e-04
#
# Epoch 00022: val_loss did not improve from 0.00086
# Epoch 23/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 3.1263e-04 - val_loss: 8.3579e-04
#
# Epoch 00023: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.9496e-04 - val_loss: 8.2420e-04
#
# Epoch 00024: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 2.9037e-04 - val_loss: 8.5890e-04
#
# Epoch 00025: val_loss did not improve from 0.00082
# Epoch 26/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.8308e-04 - val_loss: 8.1969e-04
#
# Epoch 00026: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.7874e-04 - val_loss: 8.0530e-04
#
# Epoch 00027: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 2.7251e-04 - val_loss: 8.0872e-04
#
# Epoch 00028: val_loss did not improve from 0.00081
# Epoch 29/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 2.6352e-04 - val_loss: 7.7301e-04
#
# Epoch 00029: val_loss improved from 0.00081 to 0.00077, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 2.5725e-04 - val_loss: 7.8082e-04
#
# Epoch 00030: val_loss did not improve from 0.00077
# Epoch 31/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 2.5180e-04 - val_loss: 8.1842e-04
#
# Epoch 00031: val_loss did not improve from 0.00077
# Epoch 32/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 2.5036e-04 - val_loss: 8.0314e-04
#
# Epoch 00032: val_loss did not improve from 0.00077
# Epoch 33/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 2.4007e-04 - val_loss: 7.7095e-04
#
# Epoch 00033: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 2.3235e-04 - val_loss: 7.6299e-04
#
# Epoch 00034: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 2.3868e-04 - val_loss: 7.5238e-04
#
# Epoch 00035: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 2.2723e-04 - val_loss: 7.5522e-04
#
# Epoch 00036: val_loss did not improve from 0.00075
# Epoch 37/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.1865e-04 - val_loss: 7.6191e-04
#
# Epoch 00037: val_loss did not improve from 0.00075
# Epoch 38/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 2.1893e-04 - val_loss: 7.5632e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.1655e-04 - val_loss: 7.9057e-04
#
# Epoch 00039: val_loss did not improve from 0.00075
# Epoch 40/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 2.1564e-04 - val_loss: 7.8610e-04
#
# Epoch 00040: val_loss did not improve from 0.00075
# Epoch 41/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 2.0469e-04 - val_loss: 8.1466e-04
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 2.0939e-04 - val_loss: 7.5418e-04
#
# Epoch 00042: val_loss did not improve from 0.00075
# Epoch 43/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.1191e-04 - val_loss: 7.6874e-04
#
# Epoch 00043: val_loss did not improve from 0.00075
# Epoch 44/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 2.0095e-04 - val_loss: 7.6911e-04
#
# Epoch 00044: val_loss did not improve from 0.00075
# Epoch 45/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.9449e-04 - val_loss: 8.3078e-04
#
# Epoch 00045: val_loss did not improve from 0.00075
# Epoch 46/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.9684e-04 - val_loss: 7.4972e-04
#
# Epoch 00046: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.8955e-04 - val_loss: 7.6023e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.8662e-04 - val_loss: 7.6974e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.8189e-04 - val_loss: 7.4191e-04
#
# Epoch 00049: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.8349e-04 - val_loss: 7.7411e-04
#
# Epoch 00050: val_loss did not improve from 0.00074
# Epoch 51/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.7776e-04 - val_loss: 7.7794e-04
#
# Epoch 00051: val_loss did not improve from 0.00074
# Epoch 52/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.8019e-04 - val_loss: 7.3160e-04
#
# Epoch 00052: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.7112e-04 - val_loss: 7.2170e-04
#
# Epoch 00053: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.7694e-04 - val_loss: 7.3704e-04
#
# Epoch 00054: val_loss did not improve from 0.00072
# Epoch 55/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.7337e-04 - val_loss: 7.3069e-04
#
# Epoch 00055: val_loss did not improve from 0.00072
# Epoch 56/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.7114e-04 - val_loss: 7.2681e-04
#
# Epoch 00056: val_loss did not improve from 0.00072
# Epoch 57/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.6592e-04 - val_loss: 7.7169e-04
#
# Epoch 00057: val_loss did not improve from 0.00072
# Epoch 58/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.6980e-04 - val_loss: 7.3898e-04
#
# Epoch 00058: val_loss did not improve from 0.00072
# Epoch 59/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.6915e-04 - val_loss: 7.4258e-04
#
# Epoch 00059: val_loss did not improve from 0.00072
# Epoch 60/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.6083e-04 - val_loss: 7.1115e-04
#
# Epoch 00060: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 61/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.6380e-04 - val_loss: 7.1970e-04
#
# Epoch 00061: val_loss did not improve from 0.00071
# Epoch 62/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.6318e-04 - val_loss: 7.2287e-04
#
# Epoch 00062: val_loss did not improve from 0.00071
# Epoch 63/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.6121e-04 - val_loss: 7.2237e-04
#
# Epoch 00063: val_loss did not improve from 0.00071
# Epoch 64/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.5893e-04 - val_loss: 7.2762e-04
#
# Epoch 00064: val_loss did not improve from 0.00071
# Epoch 65/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.5302e-04 - val_loss: 7.2778e-04
#
# Epoch 00065: val_loss did not improve from 0.00071
# Epoch 66/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.4923e-04 - val_loss: 7.2221e-04
#
# Epoch 00066: val_loss did not improve from 0.00071
# Epoch 67/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.5401e-04 - val_loss: 7.4214e-04
#
# Epoch 00067: val_loss did not improve from 0.00071
# Epoch 68/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.5351e-04 - val_loss: 7.1134e-04
#
# Epoch 00068: val_loss did not improve from 0.00071
# Epoch 69/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.4783e-04 - val_loss: 7.4693e-04
#
# Epoch 00069: val_loss did not improve from 0.00071
# Epoch 70/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.4082e-04 - val_loss: 7.5963e-04
#
# Epoch 00070: val_loss did not improve from 0.00071
# Epoch 71/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.3896e-04 - val_loss: 7.5012e-04
#
# Epoch 00071: val_loss did not improve from 0.00071
# Epoch 72/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.4454e-04 - val_loss: 7.3070e-04
#
# Epoch 00072: val_loss did not improve from 0.00071
# Epoch 73/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.4133e-04 - val_loss: 7.5370e-04
#
# Epoch 00073: val_loss did not improve from 0.00071
# Epoch 74/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.4398e-04 - val_loss: 7.5912e-04
#
# Epoch 00074: val_loss did not improve from 0.00071
# Epoch 75/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.4106e-04 - val_loss: 7.3980e-04
#
# Epoch 00075: val_loss did not improve from 0.00071
# Epoch 76/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.4177e-04 - val_loss: 7.2721e-04
#
# Epoch 00076: val_loss did not improve from 0.00071
# Epoch 77/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.3448e-04 - val_loss: 7.4806e-04
#
# Epoch 00077: val_loss did not improve from 0.00071
# Epoch 78/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.3975e-04 - val_loss: 7.8884e-04
#
# Epoch 00078: val_loss did not improve from 0.00071
# Epoch 79/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.3297e-04 - val_loss: 7.5152e-04
#
# Epoch 00079: val_loss did not improve from 0.00071
# Epoch 80/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.3360e-04 - val_loss: 7.5058e-04
#
# Epoch 00080: val_loss did not improve from 0.00071
# Epoch 81/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.3326e-04 - val_loss: 7.8352e-04
#
# Epoch 00081: val_loss did not improve from 0.00071
# Epoch 82/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.3014e-04 - val_loss: 7.4121e-04
#
# Epoch 00082: val_loss did not improve from 0.00071
# Epoch 83/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.3078e-04 - val_loss: 7.7571e-04
#
# Epoch 00083: val_loss did not improve from 0.00071
# Epoch 84/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.3074e-04 - val_loss: 7.6107e-04
#
# Epoch 00084: val_loss did not improve from 0.00071
# Epoch 85/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.3014e-04 - val_loss: 7.4595e-04
#
# Epoch 00085: val_loss did not improve from 0.00071
# Epoch 86/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.2593e-04 - val_loss: 7.4024e-04
#
# Epoch 00086: val_loss did not improve from 0.00071
# Epoch 87/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.2453e-04 - val_loss: 7.2895e-04
#
# Epoch 00087: val_loss did not improve from 0.00071
# Epoch 88/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.2620e-04 - val_loss: 7.7355e-04
#
# Epoch 00088: val_loss did not improve from 0.00071
# Epoch 89/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.2848e-04 - val_loss: 7.2193e-04
#
# Epoch 00089: val_loss did not improve from 0.00071
# Epoch 90/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.3158e-04 - val_loss: 7.9991e-04
#
# Epoch 00090: val_loss did not improve from 0.00071
# Epoch 91/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.2362e-04 - val_loss: 7.5732e-04
#
# Epoch 00091: val_loss did not improve from 0.00071
# Epoch 92/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.2522e-04 - val_loss: 7.7439e-04
#
# Epoch 00092: val_loss did not improve from 0.00071
# Epoch 93/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.2542e-04 - val_loss: 7.3792e-04
#
# Epoch 00093: val_loss did not improve from 0.00071
# Epoch 94/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.1879e-04 - val_loss: 7.8560e-04
#
# Epoch 00094: val_loss did not improve from 0.00071
# Epoch 95/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.2162e-04 - val_loss: 7.5977e-04
#
# Epoch 00095: val_loss did not improve from 0.00071
# Epoch 96/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.2233e-04 - val_loss: 7.5080e-04
#
# Epoch 00096: val_loss did not improve from 0.00071
# Epoch 97/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.2205e-04 - val_loss: 7.3388e-04
#
# Epoch 00097: val_loss did not improve from 0.00071
# Epoch 98/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.1705e-04 - val_loss: 7.4645e-04
#
# Epoch 00098: val_loss did not improve from 0.00071
# Epoch 99/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.1540e-04 - val_loss: 7.3118e-04
#
# Epoch 00099: val_loss did not improve from 0.00071
# Epoch 100/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.1486e-04 - val_loss: 7.3596e-04
#
# Epoch 00100: val_loss did not improve from 0.00071
# Epoch 101/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.1395e-04 - val_loss: 7.6363e-04
#
# Epoch 00101: val_loss did not improve from 0.00071
# Epoch 102/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.1328e-04 - val_loss: 7.3070e-04
#
# Epoch 00102: val_loss did not improve from 0.00071
# Epoch 103/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.1076e-04 - val_loss: 7.2320e-04
#
# Epoch 00103: val_loss did not improve from 0.00071
# Epoch 104/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.1065e-04 - val_loss: 7.2989e-04
#
# Epoch 00104: val_loss did not improve from 0.00071
# Epoch 105/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.0922e-04 - val_loss: 7.3712e-04
#
# Epoch 00105: val_loss did not improve from 0.00071
# Epoch 106/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.0568e-04 - val_loss: 7.3863e-04
#
# Epoch 00106: val_loss did not improve from 0.00071
# Epoch 107/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.0706e-04 - val_loss: 7.4504e-04
#
# Epoch 00107: val_loss did not improve from 0.00071
# Epoch 108/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.0721e-04 - val_loss: 7.2064e-04
#
# Epoch 00108: val_loss did not improve from 0.00071
# Epoch 109/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.1073e-04 - val_loss: 7.3443e-04
#
# Epoch 00109: val_loss did not improve from 0.00071
# Epoch 110/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.0460e-04 - val_loss: 7.2970e-04
#
# Epoch 00110: val_loss did not improve from 0.00071
# Epoch 111/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.0621e-04 - val_loss: 7.1447e-04
#
# Epoch 00111: val_loss did not improve from 0.00071
# Epoch 112/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.0543e-04 - val_loss: 7.3156e-04
#
# Epoch 00112: val_loss did not improve from 0.00071
# Epoch 113/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0540e-04 - val_loss: 7.4594e-04
#
# Epoch 00113: val_loss did not improve from 0.00071
# Epoch 114/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.0035e-04 - val_loss: 7.5681e-04
#
# Epoch 00114: val_loss did not improve from 0.00071
# Epoch 115/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.0550e-04 - val_loss: 7.7433e-04
#
# Epoch 00115: val_loss did not improve from 0.00071
# Epoch 116/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.0283e-04 - val_loss: 7.6192e-04
#
# Epoch 00116: val_loss did not improve from 0.00071
# Epoch 117/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.0085e-04 - val_loss: 7.3905e-04
#
# Epoch 00117: val_loss did not improve from 0.00071
# Epoch 118/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0094e-04 - val_loss: 7.3803e-04
#
# Epoch 00118: val_loss did not improve from 0.00071
# Epoch 119/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 9.6688e-05 - val_loss: 7.2481e-04
#
# Epoch 00119: val_loss did not improve from 0.00071
# Epoch 120/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 9.8281e-05 - val_loss: 7.5182e-04
#
# Epoch 00120: val_loss did not improve from 0.00071
# Epoch 121/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.9922e-05 - val_loss: 7.4211e-04
#
# Epoch 00121: val_loss did not improve from 0.00071
# Epoch 122/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.9098e-05 - val_loss: 7.5123e-04
#
# Epoch 00122: val_loss did not improve from 0.00071
# Epoch 123/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 9.8962e-05 - val_loss: 7.4612e-04
#
# Epoch 00123: val_loss did not improve from 0.00071
# Epoch 124/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.7235e-05 - val_loss: 7.3545e-04
#
# Epoch 00124: val_loss did not improve from 0.00071
# Epoch 125/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.0020e-04 - val_loss: 7.5592e-04
#
# Epoch 00125: val_loss did not improve from 0.00071
# Epoch 126/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 9.4845e-05 - val_loss: 7.5436e-04
#
# Epoch 00126: val_loss did not improve from 0.00071
# Epoch 127/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 9.9091e-05 - val_loss: 7.7246e-04
#
# Epoch 00127: val_loss did not improve from 0.00071
# Epoch 128/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 9.6631e-05 - val_loss: 7.3015e-04
#
# Epoch 00128: val_loss did not improve from 0.00071
# Epoch 129/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 9.7259e-05 - val_loss: 7.2786e-04
#
# Epoch 00129: val_loss did not improve from 0.00071
# Epoch 130/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.5292e-05 - val_loss: 7.6274e-04
#
# Epoch 00130: val_loss did not improve from 0.00071
# Epoch 131/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 9.4921e-05 - val_loss: 7.4485e-04
#
# Epoch 00131: val_loss did not improve from 0.00071
# Epoch 132/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 9.4202e-05 - val_loss: 7.4419e-04
#
# Epoch 00132: val_loss did not improve from 0.00071
# Epoch 133/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 9.7404e-05 - val_loss: 7.3647e-04
#
# Epoch 00133: val_loss did not improve from 0.00071
# Epoch 134/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 9.3537e-05 - val_loss: 7.5034e-04
#
# Epoch 00134: val_loss did not improve from 0.00071
# Epoch 135/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 9.2482e-05 - val_loss: 7.9062e-04
#
# Epoch 00135: val_loss did not improve from 0.00071
# Epoch 136/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 9.1855e-05 - val_loss: 7.3279e-04
#
# Epoch 00136: val_loss did not improve from 0.00071
# Epoch 137/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 9.2165e-05 - val_loss: 7.3553e-04
#
# Epoch 00137: val_loss did not improve from 0.00071
# Epoch 138/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 9.4034e-05 - val_loss: 7.4967e-04
#
# Epoch 00138: val_loss did not improve from 0.00071
# Epoch 139/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 9.0664e-05 - val_loss: 7.3188e-04
#
# Epoch 00139: val_loss did not improve from 0.00071
# Epoch 140/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 8.9504e-05 - val_loss: 7.4624e-04
#
# Epoch 00140: val_loss did not improve from 0.00071
# Epoch 141/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 8.9735e-05 - val_loss: 7.8080e-04
#
# Epoch 00141: val_loss did not improve from 0.00071
# Epoch 142/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 9.2512e-05 - val_loss: 7.0698e-04
#
# Epoch 00142: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 143/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.1746e-05 - val_loss: 7.3889e-04
#
# Epoch 00143: val_loss did not improve from 0.00071
# Epoch 144/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 8.8347e-05 - val_loss: 7.4951e-04
#
# Epoch 00144: val_loss did not improve from 0.00071
# Epoch 145/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 8.7162e-05 - val_loss: 7.5463e-04
#
# Epoch 00145: val_loss did not improve from 0.00071
# Epoch 146/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 8.5538e-05 - val_loss: 7.3646e-04
#
# Epoch 00146: val_loss did not improve from 0.00071
# Epoch 147/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 8.5352e-05 - val_loss: 7.3653e-04
#
# Epoch 00147: val_loss did not improve from 0.00071
# Epoch 148/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 8.5108e-05 - val_loss: 7.2840e-04
#
# Epoch 00148: val_loss did not improve from 0.00071
# Epoch 149/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 8.7166e-05 - val_loss: 7.9675e-04
#
# Epoch 00149: val_loss did not improve from 0.00071
# Epoch 150/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 8.8508e-05 - val_loss: 7.5145e-04
#
# Epoch 00150: val_loss did not improve from 0.00071

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# 直接參考解答....

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 1s 341us/step - loss: 0.0045 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00206, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00206 to 0.00186, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 188us/step - loss: 0.0011 - val_loss: 0.0017
#
# Epoch 00003: val_loss improved from 0.00186 to 0.00170, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 183us/step - loss: 8.6465e-04 - val_loss: 0.0016
#
# Epoch 00004: val_loss improved from 0.00170 to 0.00158, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 7.0601e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00158 to 0.00122, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 5.8889e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00122 to 0.00111, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 5.1336e-04 - val_loss: 0.0010
#
# Epoch 00007: val_loss improved from 0.00111 to 0.00101, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 4.6225e-04 - val_loss: 9.5278e-04
#
# Epoch 00008: val_loss improved from 0.00101 to 0.00095, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 4.3087e-04 - val_loss: 8.6667e-04
#
# Epoch 00009: val_loss improved from 0.00095 to 0.00087, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 3.9109e-04 - val_loss: 7.8907e-04
#
# Epoch 00010: val_loss improved from 0.00087 to 0.00079, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 3.6387e-04 - val_loss: 8.3066e-04
#
# Epoch 00011: val_loss did not improve from 0.00079
# Epoch 12/150
# 3424/3424 [==============================] - 1s 182us/step - loss: 3.4653e-04 - val_loss: 7.6986e-04
#
# Epoch 00012: val_loss improved from 0.00079 to 0.00077, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 3.3256e-04 - val_loss: 7.5410e-04
#
# Epoch 00013: val_loss improved from 0.00077 to 0.00075, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 3.1306e-04 - val_loss: 7.1267e-04
#
# Epoch 00014: val_loss improved from 0.00075 to 0.00071, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 2.9397e-04 - val_loss: 7.3619e-04
#
# Epoch 00015: val_loss did not improve from 0.00071
# Epoch 16/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 2.8356e-04 - val_loss: 7.2140e-04
#
# Epoch 00016: val_loss did not improve from 0.00071
# Epoch 17/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 2.7496e-04 - val_loss: 7.0052e-04
#
# Epoch 00017: val_loss improved from 0.00071 to 0.00070, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 2.6608e-04 - val_loss: 6.8281e-04
#
# Epoch 00018: val_loss improved from 0.00070 to 0.00068, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 2.5811e-04 - val_loss: 6.6395e-04
#
# Epoch 00019: val_loss improved from 0.00068 to 0.00066, saving model to best_weights_augment.h5
# Epoch 20/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 2.4878e-04 - val_loss: 6.6615e-04
#
# Epoch 00020: val_loss did not improve from 0.00066
# Epoch 21/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 2.4230e-04 - val_loss: 6.7139e-04
#
# Epoch 00021: val_loss did not improve from 0.00066
# Epoch 22/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 2.4527e-04 - val_loss: 6.7518e-04
#
# Epoch 00022: val_loss did not improve from 0.00066
# Epoch 23/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 2.3118e-04 - val_loss: 6.4069e-04
#
# Epoch 00023: val_loss improved from 0.00066 to 0.00064, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 2.2485e-04 - val_loss: 6.5590e-04
#
# Epoch 00024: val_loss did not improve from 0.00064
# Epoch 25/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 2.1905e-04 - val_loss: 6.4607e-04
#
# Epoch 00025: val_loss did not improve from 0.00064
# Epoch 26/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 2.1648e-04 - val_loss: 6.7864e-04
#
# Epoch 00026: val_loss did not improve from 0.00064
# Epoch 27/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 2.0711e-04 - val_loss: 6.6138e-04
#
# Epoch 00027: val_loss did not improve from 0.00064
# Epoch 28/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 2.0353e-04 - val_loss: 6.7332e-04
#
# Epoch 00028: val_loss did not improve from 0.00064
# Epoch 29/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 2.0560e-04 - val_loss: 6.5359e-04
#
# Epoch 00029: val_loss did not improve from 0.00064
# Epoch 30/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.9968e-04 - val_loss: 6.8724e-04
#
# Epoch 00030: val_loss did not improve from 0.00064
# Epoch 31/150
# 3424/3424 [==============================] - 1s 177us/step - loss: 1.9601e-04 - val_loss: 6.3632e-04
#
# Epoch 00031: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 32/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 1.9002e-04 - val_loss: 6.0980e-04
#
# Epoch 00032: val_loss improved from 0.00064 to 0.00061, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 1s 180us/step - loss: 1.8799e-04 - val_loss: 6.8594e-04
#
# Epoch 00033: val_loss did not improve from 0.00061
# Epoch 34/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.8065e-04 - val_loss: 6.3512e-04
#
# Epoch 00034: val_loss did not improve from 0.00061
# Epoch 35/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.8009e-04 - val_loss: 6.4748e-04
#
# Epoch 00035: val_loss did not improve from 0.00061
# Epoch 36/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.7939e-04 - val_loss: 6.6401e-04
#
# Epoch 00036: val_loss did not improve from 0.00061
# Epoch 37/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.7570e-04 - val_loss: 6.1706e-04
#
# Epoch 00037: val_loss did not improve from 0.00061
# Epoch 38/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 1.7193e-04 - val_loss: 6.2875e-04
#
# Epoch 00038: val_loss did not improve from 0.00061
# Epoch 39/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 1.6414e-04 - val_loss: 6.1604e-04
#
# Epoch 00039: val_loss did not improve from 0.00061
# Epoch 40/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.6648e-04 - val_loss: 6.6220e-04
#
# Epoch 00040: val_loss did not improve from 0.00061
# Epoch 41/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.6464e-04 - val_loss: 6.1242e-04
#
# Epoch 00041: val_loss did not improve from 0.00061
# Epoch 42/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.5971e-04 - val_loss: 6.1871e-04
#
# Epoch 00042: val_loss did not improve from 0.00061
# Epoch 43/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.5631e-04 - val_loss: 6.1584e-04
#
# Epoch 00043: val_loss did not improve from 0.00061
# Epoch 44/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 1.5845e-04 - val_loss: 6.2743e-04
#
# Epoch 00044: val_loss did not improve from 0.00061
# Epoch 45/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.4958e-04 - val_loss: 6.1885e-04
#
# Epoch 00045: val_loss did not improve from 0.00061
# Epoch 46/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.4973e-04 - val_loss: 6.2869e-04
#
# Epoch 00046: val_loss did not improve from 0.00061
# Epoch 47/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 1.4781e-04 - val_loss: 5.8321e-04
#
# Epoch 00047: val_loss improved from 0.00061 to 0.00058, saving model to best_weights_augment.h5
# Epoch 48/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.4738e-04 - val_loss: 6.1654e-04
#
# Epoch 00048: val_loss did not improve from 0.00058
# Epoch 49/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 1.4556e-04 - val_loss: 6.2132e-04
#
# Epoch 00049: val_loss did not improve from 0.00058
# Epoch 50/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.4696e-04 - val_loss: 6.1201e-04
#
# Epoch 00050: val_loss did not improve from 0.00058
# Epoch 51/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.4416e-04 - val_loss: 6.8229e-04
#
# Epoch 00051: val_loss did not improve from 0.00058
# Epoch 52/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.4116e-04 - val_loss: 5.9842e-04
#
# Epoch 00052: val_loss did not improve from 0.00058
# Epoch 53/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.4229e-04 - val_loss: 6.1612e-04
#
# Epoch 00053: val_loss did not improve from 0.00058
# Epoch 54/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.3469e-04 - val_loss: 6.0767e-04
#
# Epoch 00054: val_loss did not improve from 0.00058
# Epoch 55/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.3379e-04 - val_loss: 6.1124e-04
#
# Epoch 00055: val_loss did not improve from 0.00058
# Epoch 56/150
# 3424/3424 [==============================] - 1s 185us/step - loss: 1.3293e-04 - val_loss: 6.2699e-04
#
# Epoch 00056: val_loss did not improve from 0.00058
# Epoch 57/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.3165e-04 - val_loss: 6.3266e-04
#
# Epoch 00057: val_loss did not improve from 0.00058
# Epoch 58/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.3264e-04 - val_loss: 6.1698e-04
#
# Epoch 00058: val_loss did not improve from 0.00058
# Epoch 59/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.3140e-04 - val_loss: 6.2139e-04
#
# Epoch 00059: val_loss did not improve from 0.00058
# Epoch 60/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.2850e-04 - val_loss: 5.9637e-04
#
# Epoch 00060: val_loss did not improve from 0.00058
# Epoch 61/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.2862e-04 - val_loss: 6.1624e-04
#
# Epoch 00061: val_loss did not improve from 0.00058
# Epoch 62/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.2744e-04 - val_loss: 6.4577e-04
#
# Epoch 00062: val_loss did not improve from 0.00058
# Epoch 63/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 1.2296e-04 - val_loss: 6.2585e-04
#
# Epoch 00063: val_loss did not improve from 0.00058
# Epoch 64/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 1.2251e-04 - val_loss: 6.1802e-04
#
# Epoch 00064: val_loss did not improve from 0.00058
# Epoch 65/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.2433e-04 - val_loss: 6.1715e-04
#
# Epoch 00065: val_loss did not improve from 0.00058
# Epoch 66/150
# 3424/3424 [==============================] - 1s 185us/step - loss: 1.1975e-04 - val_loss: 6.5089e-04
#
# Epoch 00066: val_loss did not improve from 0.00058
# Epoch 67/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 1.2124e-04 - val_loss: 6.1213e-04
#
# Epoch 00067: val_loss did not improve from 0.00058
# Epoch 68/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.1812e-04 - val_loss: 6.2698e-04
#
# Epoch 00068: val_loss did not improve from 0.00058
# Epoch 69/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.1529e-04 - val_loss: 6.0356e-04
#
# Epoch 00069: val_loss did not improve from 0.00058
# Epoch 70/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.1615e-04 - val_loss: 6.0371e-04
#
# Epoch 00070: val_loss did not improve from 0.00058
# Epoch 71/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.1375e-04 - val_loss: 6.3780e-04
#
# Epoch 00071: val_loss did not improve from 0.00058
# Epoch 72/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.1496e-04 - val_loss: 6.3224e-04
#
# Epoch 00072: val_loss did not improve from 0.00058
# Epoch 73/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.1280e-04 - val_loss: 6.4990e-04
#
# Epoch 00073: val_loss did not improve from 0.00058
# Epoch 74/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 1.1232e-04 - val_loss: 6.5272e-04
#
# Epoch 00074: val_loss did not improve from 0.00058
# Epoch 75/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 1.1025e-04 - val_loss: 6.4156e-04
#
# Epoch 00075: val_loss did not improve from 0.00058
# Epoch 76/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.0817e-04 - val_loss: 6.3517e-04
#
# Epoch 00076: val_loss did not improve from 0.00058
# Epoch 77/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.0946e-04 - val_loss: 6.1812e-04
#
# Epoch 00077: val_loss did not improve from 0.00058
# Epoch 78/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.1112e-04 - val_loss: 6.1667e-04
#
# Epoch 00078: val_loss did not improve from 0.00058
# Epoch 79/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.0639e-04 - val_loss: 6.3603e-04
#
# Epoch 00079: val_loss did not improve from 0.00058
# Epoch 80/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.0450e-04 - val_loss: 6.5830e-04
#
# Epoch 00080: val_loss did not improve from 0.00058
# Epoch 81/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.0694e-04 - val_loss: 6.2185e-04
#
# Epoch 00081: val_loss did not improve from 0.00058
# Epoch 82/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.0395e-04 - val_loss: 6.2172e-04
#
# Epoch 00082: val_loss did not improve from 0.00058
# Epoch 83/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.0497e-04 - val_loss: 6.1236e-04
#
# Epoch 00083: val_loss did not improve from 0.00058
# Epoch 84/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.0514e-04 - val_loss: 5.9602e-04
#
# Epoch 00084: val_loss did not improve from 0.00058
# Epoch 85/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.0498e-04 - val_loss: 6.3555e-04
#
# Epoch 00085: val_loss did not improve from 0.00058
# Epoch 86/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.0354e-04 - val_loss: 6.1288e-04
#
# Epoch 00086: val_loss did not improve from 0.00058
# Epoch 87/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 1.0059e-04 - val_loss: 6.0988e-04
#
# Epoch 00087: val_loss did not improve from 0.00058
# Epoch 88/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.0045e-04 - val_loss: 6.3076e-04
#
# Epoch 00088: val_loss did not improve from 0.00058
# Epoch 89/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 9.9097e-05 - val_loss: 5.9511e-04
#
# Epoch 00089: val_loss did not improve from 0.00058
# Epoch 90/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 1.0009e-04 - val_loss: 6.4845e-04
#
# Epoch 00090: val_loss did not improve from 0.00058
# Epoch 91/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 9.8278e-05 - val_loss: 6.4845e-04
#
# Epoch 00091: val_loss did not improve from 0.00058
# Epoch 92/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 9.9684e-05 - val_loss: 6.1549e-04
#
# Epoch 00092: val_loss did not improve from 0.00058
# Epoch 93/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 9.8957e-05 - val_loss: 6.0590e-04
#
# Epoch 00093: val_loss did not improve from 0.00058
# Epoch 94/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 9.7932e-05 - val_loss: 6.1391e-04
#
# Epoch 00094: val_loss did not improve from 0.00058
# Epoch 95/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 9.6903e-05 - val_loss: 6.1581e-04
#
# Epoch 00095: val_loss did not improve from 0.00058
# Epoch 96/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.6831e-05 - val_loss: 6.2851e-04
#
# Epoch 00096: val_loss did not improve from 0.00058
# Epoch 97/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.5988e-05 - val_loss: 6.3424e-04
#
# Epoch 00097: val_loss did not improve from 0.00058
# Epoch 98/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 9.5846e-05 - val_loss: 6.2458e-04
#
# Epoch 00098: val_loss did not improve from 0.00058
# Epoch 99/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 9.4835e-05 - val_loss: 6.2471e-04
#
# Epoch 00099: val_loss did not improve from 0.00058
# Epoch 100/150
# 3424/3424 [==============================] - 1s 180us/step - loss: 9.6808e-05 - val_loss: 6.3284e-04
#
# Epoch 00100: val_loss did not improve from 0.00058
# Epoch 101/150
# 3424/3424 [==============================] - 1s 181us/step - loss: 9.5158e-05 - val_loss: 6.2575e-04
#
# Epoch 00101: val_loss did not improve from 0.00058
# Epoch 102/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 9.2008e-05 - val_loss: 5.9944e-04
#
# Epoch 00102: val_loss did not improve from 0.00058
# Epoch 103/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.2181e-05 - val_loss: 6.2311e-04
#
# Epoch 00103: val_loss did not improve from 0.00058
# Epoch 104/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 9.1575e-05 - val_loss: 6.1919e-04
#
# Epoch 00104: val_loss did not improve from 0.00058
# Epoch 105/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.0952e-05 - val_loss: 6.1770e-04
#
# Epoch 00105: val_loss did not improve from 0.00058
# Epoch 106/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 9.3759e-05 - val_loss: 6.0681e-04
#
# Epoch 00106: val_loss did not improve from 0.00058
# Epoch 107/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.0927e-05 - val_loss: 6.0523e-04
#
# Epoch 00107: val_loss did not improve from 0.00058
# Epoch 108/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 8.9342e-05 - val_loss: 6.1713e-04
#
# Epoch 00108: val_loss did not improve from 0.00058
# Epoch 109/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 9.0511e-05 - val_loss: 6.2570e-04
#
# Epoch 00109: val_loss did not improve from 0.00058
# Epoch 110/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.9658e-05 - val_loss: 6.2551e-04
#
# Epoch 00110: val_loss did not improve from 0.00058
# Epoch 111/150
# 3424/3424 [==============================] - 1s 180us/step - loss: 8.9176e-05 - val_loss: 6.1131e-04
#
# Epoch 00111: val_loss did not improve from 0.00058
# Epoch 112/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 8.7042e-05 - val_loss: 6.2202e-04
#
# Epoch 00112: val_loss did not improve from 0.00058
# Epoch 113/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.8952e-05 - val_loss: 5.9782e-04
#
# Epoch 00113: val_loss did not improve from 0.00058
# Epoch 114/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.8056e-05 - val_loss: 6.1808e-04
#
# Epoch 00114: val_loss did not improve from 0.00058
# Epoch 115/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 9.1266e-05 - val_loss: 6.1955e-04
#
# Epoch 00115: val_loss did not improve from 0.00058
# Epoch 116/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.9508e-05 - val_loss: 6.3325e-04
#
# Epoch 00116: val_loss did not improve from 0.00058
# Epoch 117/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 9.2237e-05 - val_loss: 6.1775e-04
#
# Epoch 00117: val_loss did not improve from 0.00058
# Epoch 118/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.9758e-05 - val_loss: 6.4471e-04
#
# Epoch 00118: val_loss did not improve from 0.00058
# Epoch 119/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.0871e-05 - val_loss: 6.3653e-04
#
# Epoch 00119: val_loss did not improve from 0.00058
# Epoch 120/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.8827e-05 - val_loss: 6.1185e-04
#
# Epoch 00120: val_loss did not improve from 0.00058
# Epoch 121/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.7272e-05 - val_loss: 6.1581e-04
#
# Epoch 00121: val_loss did not improve from 0.00058
# Epoch 122/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.8531e-05 - val_loss: 6.2138e-04
#
# Epoch 00122: val_loss did not improve from 0.00058
# Epoch 123/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 8.5828e-05 - val_loss: 6.2874e-04
#
# Epoch 00123: val_loss did not improve from 0.00058
# Epoch 124/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.4977e-05 - val_loss: 6.6238e-04
#
# Epoch 00124: val_loss did not improve from 0.00058
# Epoch 125/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 8.6517e-05 - val_loss: 6.1717e-04
#
# Epoch 00125: val_loss did not improve from 0.00058
# Epoch 126/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.8989e-05 - val_loss: 6.3832e-04
#
# Epoch 00126: val_loss did not improve from 0.00058
# Epoch 127/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 8.4039e-05 - val_loss: 6.3278e-04
#
# Epoch 00127: val_loss did not improve from 0.00058
# Epoch 128/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 8.4831e-05 - val_loss: 6.1729e-04
#
# Epoch 00128: val_loss did not improve from 0.00058
# Epoch 129/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.7115e-05 - val_loss: 6.3269e-04
#
# Epoch 00129: val_loss did not improve from 0.00058
# Epoch 130/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.4920e-05 - val_loss: 6.1669e-04
#
# Epoch 00130: val_loss did not improve from 0.00058
# Epoch 131/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.5734e-05 - val_loss: 6.1259e-04
#
# Epoch 00131: val_loss did not improve from 0.00058
# Epoch 132/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.2024e-05 - val_loss: 6.2446e-04
#
# Epoch 00132: val_loss did not improve from 0.00058
# Epoch 133/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 8.3012e-05 - val_loss: 6.1178e-04
#
# Epoch 00133: val_loss did not improve from 0.00058
# Epoch 134/150
# 3424/3424 [==============================] - 1s 176us/step - loss: 8.1627e-05 - val_loss: 6.2885e-04
#
# Epoch 00134: val_loss did not improve from 0.00058
# Epoch 135/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.3618e-05 - val_loss: 6.2380e-04
#
# Epoch 00135: val_loss did not improve from 0.00058
# Epoch 136/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.3453e-05 - val_loss: 6.4505e-04
#
# Epoch 00136: val_loss did not improve from 0.00058
# Epoch 137/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 8.3220e-05 - val_loss: 6.4614e-04
#
# Epoch 00137: val_loss did not improve from 0.00058
# Epoch 138/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 8.4189e-05 - val_loss: 6.1666e-04
#
# Epoch 00138: val_loss did not improve from 0.00058
# Epoch 139/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 8.3944e-05 - val_loss: 6.2544e-04
#
# Epoch 00139: val_loss did not improve from 0.00058
# Epoch 140/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.1901e-05 - val_loss: 6.3128e-04
#
# Epoch 00140: val_loss did not improve from 0.00058
# Epoch 141/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.1449e-05 - val_loss: 6.3355e-04
#
# Epoch 00141: val_loss did not improve from 0.00058
# Epoch 142/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.1596e-05 - val_loss: 6.2099e-04
#
# Epoch 00142: val_loss did not improve from 0.00058
# Epoch 143/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 8.3632e-05 - val_loss: 6.2535e-04
#
# Epoch 00143: val_loss did not improve from 0.00058
# Epoch 144/150
# 3424/3424 [==============================] - 1s 173us/step - loss: 8.5885e-05 - val_loss: 6.1926e-04
#
# Epoch 00144: val_loss did not improve from 0.00058
# Epoch 145/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.3363e-05 - val_loss: 6.3034e-04
#
# Epoch 00145: val_loss did not improve from 0.00058
# Epoch 146/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.2872e-05 - val_loss: 6.0668e-04
#
# Epoch 00146: val_loss did not improve from 0.00058
# Epoch 147/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 8.0157e-05 - val_loss: 6.3994e-04
#
# Epoch 00147: val_loss did not improve from 0.00058
# Epoch 148/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.1627e-05 - val_loss: 6.2478e-04
#
# Epoch 00148: val_loss did not improve from 0.00058
# Epoch 149/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.0109e-05 - val_loss: 6.1178e-04
#
# Epoch 00149: val_loss did not improve from 0.00058
# Epoch 150/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 8.1562e-05 - val_loss: 6.3178e-04
#
# Epoch 00150: val_loss did not improve from 0.00058

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
